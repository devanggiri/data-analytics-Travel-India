# %%
import pandas as pd

# Load the data into a DataFrame
df_t = pd.read_csv('tourist_spots.csv')

# Sort the DataFrame based on a specific column, for example, 'Name'
df_travel = df_t.sort_values(by='State')

# Save the sorted DataFrame to a new CSV file
df_travel.to_csv('tourist_spotss.csv', index=False)
# Display the sorted DataFrame (optional)
print(df_travel)
# Out:
#      Unnamed: 0      Zone                        State             City  \
# 292         292  Southern  Andaman and Nicobar Islands      Neil Island
# 291         291  Southern  Andaman and Nicobar Islands  Havelock Island
# 290         290  Southern  Andaman and Nicobar Islands       Port Blair
# 293         293  Southern  Andaman and Nicobar Islands  Baratang Island
# 253         253  Southern               Andhra Pradesh          Kurnool
# ..          ...       ...                          ...              ...
# 45           45   Eastern                  West Bengal          Kolkata
# 44           44   Eastern                  West Bengal          Kolkata
# 43           43   Eastern                  West Bengal          Kolkata
# 50           50   Eastern                  West Bengal          Kolkata
# 215         215   Eastern                  West Bengal       Darjeeling
#
#                          Name             Type Establishment Year  \
# 292           Bharatpur Beach            Beach            Unknown
# 291          Radhanagar Beach            Beach            Unknown
# 290             Cellular Jail         Landmark               1906
# 293           Limestone Caves  Natural Feature            Unknown
# 253               Belum Caves             Cave            Unknown
# ..                        ...              ...                ...
# 45   Dakshineswar Kali Temple           Temple               1855
# 44              Indian Museum           Museum               1814
# 43              Howrah Bridge           Bridge               1943
# 50                 Belur Math             Site               1898
# 215                Tiger Hill    Sunrise Point            Unknown
#
#      time needed to visit in hrs  Google review rating  Entrance Fee in INR  \
# 292                          1.0                   4.5                    0
# 291                          1.0                   4.8                    0
# 290                          1.5                   4.7                   30
# 293                          1.5                   4.4                  250
# 253                          1.5                   4.4                   65
# ..                           ...                   ...                  ...
# 45                           1.0                   4.7                    0
# 44                           2.0                   4.6                   50
# 43                           0.5                   4.6                    0
# 50                           1.5                   4.7                    0
# 215                          1.0                   4.5                    0
#
#     Airport with 50km Radius Weekly Off    Significance DSLR Allowed  \
# 292                       No       None          Nature          Yes
# 291                       No       None          Nature          Yes
# 290                      Yes     Monday      Historical          Yes
# 293                       No       None          Nature          Yes
# 253                      Yes       None  Natural Wonder          Yes
# ..                       ...        ...             ...          ...
# 45                       Yes       None       Religious          Yes
# 44                       Yes     Monday      Historical          Yes
# 43                       Yes       None   Architectural           No
# 50                       Yes       None       Religious          Yes
# 215                       No       None          Nature          Yes
#
#      Number of google review in lakhs Best Time to visit  Entry Fee  \
# 292                             0.040            Morning        NaN
# 291                             0.090            Morning        NaN
# 290                             0.120          Afternoon        NaN
# 293                             0.015            Morning        NaN
# 253                             0.110          Afternoon        NaN
# ..                                ...                ...        ...
# 45                              0.820            Morning        NaN
# 44                              0.180            Morning        NaN
# 43                              1.200            Anytime        NaN
# 50                              0.470            Morning        NaN
# 215                             0.025                All        NaN
#
#      Most Visited Month  Domestic visits (number of people)  \
# 292                 NaN                                 NaN
# 291                 NaN                                 NaN
# 290                 NaN                                 NaN
# 293                 NaN                                 NaN
# 253                 NaN                                 NaN
# ..                  ...                                 ...
# 45                  NaN                                 NaN
# 44                  NaN                                 NaN
# 43                  NaN                                 NaN
# 50                  NaN                                 NaN
# 215                 NaN                                 NaN
#
#      Tourist visits (number of people)
# 292                                NaN
# 291                                NaN
# 290                                NaN
# 293                                NaN
# 253                                NaN
# ..                                 ...
# 45                                 NaN
# 44                                 NaN
# 43                                 NaN
# 50                                 NaN
# 215                                NaN
#
# [325 rows x 20 columns]

# %%
# Load the data into a DataFrame
df = pd.read_csv('temperatur.csv')

# Sort the DataFrame based on a specific column, for example, 'Name'
sorted_df = df.sort_values(by='States')

# Save the sorted DataFrame to a new CSV file
sorted_df.to_csv('temperature.csv', index=False)
# Display the sorted DataFrame (optional)
print(sorted_df)
# Out:
#                         States    Jan    Feb    Mar    Apr    May   June  \
# 21  andaman and nicobarislands  26.20  26.60  27.30  28.30  27.80  27.40
# 30               andhra padesh  24.30  26.20  29.00  31.30  33.50  31.30
# 17           arunachal pradesh  -2.40  -1.00   1.60   4.80   8.00  11.20
# 22                       assam  17.60  20.20  23.90  25.10  26.10  27.30
# 0                        bihar  18.65  22.88  30.00  36.25  38.52  37.44
# 19                  chandigarh  12.20  15.40  20.80  27.50  31.30  31.70
# 28                chhattisgarh  20.00  23.60  28.00  32.60  35.10  31.10
# 8       dadra and nagar haveli  25.11  26.34  28.72  30.52  30.95  29.79
# 4                          goa  27.96  28.84  29.30  30.77  30.84  28.13
# 7                      gujarat  23.52  26.32  30.88  34.61  35.80  33.81
# 27                     haryana  15.77  19.57  26.11  33.98  38.93  39.59
# 16            himachal pradesh   6.50   8.60  12.70  17.80  22.00  23.70
# 32           jammu and kashmir  10.50  13.00  17.70  23.90  29.10  30.70
# 31                   jharkhand  15.50  19.40  23.90  28.60  29.80  27.90
# 26                   karnataka  20.70  22.80  25.40  26.60  25.50  23.20
# 11                      kerala  28.00  28.00  29.00  30.00  29.00  27.00
# 3               madhya Pradesh  20.23  24.74  30.52  36.27  39.24  35.40
# 23                 maharashtra  23.90  24.70  26.70  28.20  29.00  27.40
# 12                     manipur  20.60  24.30  28.10  30.70  30.00  27.90
# 1                    meghalaya  13.04  15.79  18.93  20.63  21.53  22.30
# 10                     mizoram  18.33  21.73  25.92  28.69  28.62  27.10
# 29                    nagaland  15.90  18.20  21.50  23.50  25.20  26.70
# 14                      odisha  21.20  24.80  28.40  30.70  31.70  30.20
# 20                  puducherry  24.80  25.70  27.40  29.20  30.40  30.20
# 2                       punjab  14.09  17.69  24.01  32.07  37.67  39.46
# 5                     rajastan  17.78  21.70  27.96  34.20  37.89  37.67
# 253         253  Southern               Andhra Pradesh          Kurnool
# ..          ...       ...                          ...              ...
# 45           45   Eastern                  West Bengal          Kolkata
# 44           44   Eastern                  West Bengal          Kolkata
# 43           43   Eastern                  West Bengal          Kolkata
# 50           50   Eastern                  West Bengal          Kolkata
# 215         215   Eastern                  West Bengal       Darjeeling
#
#                          Name             Type Establishment Year  \
# 292           Bharatpur Beach            Beach            Unknown
# 291          Radhanagar Beach            Beach            Unknown
# 290             Cellular Jail         Landmark               1906
# 293           Limestone Caves  Natural Feature            Unknown
# 253               Belum Caves             Cave            Unknown
# ..                        ...              ...                ...
# 45   Dakshineswar Kali Temple           Temple               1855
# 44              Indian Museum           Museum               1814
# 43              Howrah Bridge           Bridge               1943
# 50                 Belur Math             Site               1898
# 215                Tiger Hill    Sunrise Point            Unknown
#
#      time needed to visit in hrs  Google review rating  Entrance Fee in INR  \
# 292                          1.0                   4.5                    0
# 291                          1.0                   4.8                    0
# 290                          1.5                   4.7                   30
# 293                          1.5                   4.4                  250
# 253                          1.5                   4.4                   65
# ..                           ...                   ...                  ...
# 45                           1.0                   4.7                    0
# 44                           2.0                   4.6                   50
# 43                           0.5                   4.6                    0
# 50                           1.5                   4.7                    0
# 215                          1.0                   4.5                    0
#
#     Airport with 50km Radius Weekly Off    Significance DSLR Allowed  \
# 292                       No       None          Nature          Yes
# 291                       No       None          Nature          Yes
# 290                      Yes     Monday      Historical          Yes
# 293                       No       None          Nature          Yes
# 253                      Yes       None  Natural Wonder          Yes
# ..                       ...        ...             ...          ...
# 45                       Yes       None       Religious          Yes
# 44                       Yes     Monday      Historical          Yes
# 43                       Yes       None   Architectural           No
# 50                       Yes       None       Religious          Yes
# 215                       No       None          Nature          Yes
#
#      Number of google review in lakhs Best Time to visit  Entry Fee  \
# 292                             0.040            Morning        NaN
# 291                             0.090            Morning        NaN
# 290                             0.120          Afternoon        NaN
# 293                             0.015            Morning        NaN
# 253                             0.110          Afternoon        NaN
# ..                                ...                ...        ...
# 45                              0.820            Morning        NaN
# 44                              0.180            Morning        NaN
# 43                              1.200            Anytime        NaN
# 50                              0.470            Morning        NaN
# 215                             0.025                All        NaN
#
#      Most Visited Month  Domestic visits (number of people)  \
# 292                 NaN                                 NaN
# 291                 NaN                                 NaN
# 290                 NaN                                 NaN
# 293                 NaN                                 NaN
# 253                 NaN                                 NaN
# ..                  ...                                 ...
# 45                  NaN                                 NaN
# 44                  NaN                                 NaN
# 43                  NaN                                 NaN
# 50                  NaN                                 NaN
# 215                 NaN                                 NaN
#
#      Tourist visits (number of people)
# 292                                NaN
# 291                                NaN
# 290                                NaN
# 293                                NaN
# 253                                NaN
# ..                                 ...
# 45                                 NaN
# 44                                 NaN
# 43                                 NaN
# 50                                 NaN
# 215                                NaN
#
# [325 rows x 20 columns]>
